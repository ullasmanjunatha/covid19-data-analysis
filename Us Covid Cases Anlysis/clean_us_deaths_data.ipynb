# %%
import pandas as pd

df = pd.read_csv("RAW_us_deaths.csv")

df.head(10)
# Out:
#   Province_State    Admin2       UID iso2 iso3  code3    FIPS Country_Region  \
# 0        Alabama   Autauga  84001001   US  USA    840  1001.0             US
# 1        Alabama   Baldwin  84001003   US  USA    840  1003.0             US
# 2        Alabama   Barbour  84001005   US  USA    840  1005.0             US
# 3        Alabama      Bibb  84001007   US  USA    840  1007.0             US
# 4        Alabama    Blount  84001009   US  USA    840  1009.0             US
# 5        Alabama   Bullock  84001011   US  USA    840  1011.0             US
# 6        Alabama    Butler  84001013   US  USA    840  1013.0             US
# 7        Alabama   Calhoun  84001015   US  USA    840  1015.0             US
# 8        Alabama  Chambers  84001017   US  USA    840  1017.0             US
# 9        Alabama  Cherokee  84001019   US  USA    840  1019.0             US
#
#          Lat      Long_  ... 2/28/23  3/1/23  3/2/23  3/3/23  3/4/23  3/5/23  \
# ...

# %%
df.shape
# Out:
# (3342, 1155)

# %%
#remove useless columns

useless_columns = ['Admin2', 'UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Country_Region', 'Lat', 'Long_']

df1 = df.drop(useless_columns, axis=1, errors='ignore')

df1.head(10)
# Out:
#   Province_State           Combined_Key  Population  1/22/20  1/23/20  \
# 0        Alabama   Autauga, Alabama, US       55869        0        0
# 1        Alabama   Baldwin, Alabama, US      223234        0        0
# 2        Alabama   Barbour, Alabama, US       24686        0        0
# 3        Alabama      Bibb, Alabama, US       22394        0        0
# 4        Alabama    Blount, Alabama, US       57826        0        0
# 5        Alabama   Bullock, Alabama, US       10101        0        0
# 6        Alabama    Butler, Alabama, US       19448        0        0
# 7        Alabama   Calhoun, Alabama, US      113605        0        0
# 8        Alabama  Chambers, Alabama, US       33254        0        0
# 9        Alabama  Cherokee, Alabama, US       26196        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  ...  2/28/23  3/1/23  3/2/23  \
# 0        0        0        0        0        0  ...      230     232     232
# ...

# %%
#Aggregate countries

df1 = df1.groupby('Province_State').sum().reset_index()

df1.head(10)
# Out:
#      Province_State                                       Combined_Key  \
# 0           Alabama  Autauga, Alabama, USBaldwin, Alabama, USBarbou...
# 1            Alaska  Aleutians East, Alaska, USAleutians West, Alas...
# 2    American Samoa                                 American Samoa, US
# 3           Arizona  Apache, Arizona, USCochise, Arizona, USCoconin...
# 4          Arkansas  Arkansas, Arkansas, USAshley, Arkansas, USBaxt...
# 5        California  Alameda, California, USAlpine, California, USA...
# 6          Colorado  Adams, Colorado, USAlamosa, Colorado, USArapah...
# 7       Connecticut  Fairfield, Connecticut, USHartford, Connecticu...
# 8          Delaware  Kent, Delaware, USNew Castle, Delaware, USOut ...
# 9  Diamond Princess                               Diamond Princess, US
#
#    Population  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# 0     4903185        0        0        0        0        0        0        0
# ...

# %%
df1.shape
# Out:
# (58, 1146)

# %%
#ADD total deaths

columns_to_add = df1.columns.difference(['Province_State', 'Combined_Key', 'Population'])

df1['Total_Deaths'] = df1[columns_to_add].sum(axis=1)

df1.head(10)
# Out:
#      Province_State                                       Combined_Key  \
# 0           Alabama  Autauga, Alabama, USBaldwin, Alabama, USBarbou...
# 1            Alaska  Aleutians East, Alaska, USAleutians West, Alas...
# 2    American Samoa                                 American Samoa, US
# 3           Arizona  Apache, Arizona, USCochise, Arizona, USCoconin...
# 4          Arkansas  Arkansas, Arkansas, USAshley, Arkansas, USBaxt...
# 5        California  Alameda, California, USAlpine, California, USA...
# 6          Colorado  Adams, Colorado, USAlamosa, Colorado, USArapah...
# 7       Connecticut  Fairfield, Connecticut, USHartford, Connecticu...
# 8          Delaware  Kent, Delaware, USNew Castle, Delaware, USOut ...
# 9  Diamond Princess                               Diamond Princess, US
#
#    Population  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# 0     4903185        0        0        0        0        0        0        0
# ...

# %%
#Keep required data

df2 = df1[['Province_State', 'Total_Deaths']]

df2.head(10)
# Out:
#      Province_State  Total_Deaths
# 0           Alabama      13398261
# 1            Alaska        751555
# 2    American Samoa         10804
# 3           Arizona      20789702
# 4          Arkansas       7721989
# 5        California      65490302
# 6          Colorado       8942186
# 7       Connecticut       8911110
# 8          Delaware       2089142
# 9  Diamond Princess             0

# %%
#Export to new file

df2.to_csv("Cleaned_us_deaths.csv", index=False)
